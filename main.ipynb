# %%
import os

repo_url = "https://github.com/Zedrion/nanoGPT-clone.git"
repo_path = "/content/nanoGPT-clone"

if os.path.exists(repo_path):
    # !git -C {repo_path} fetch --all 
    # !git -C {repo_path} reset --hard origin/main
else:
    # !git clone {repo_url} {repo_path}

# %cd {repo_path}
# %matplotlib inline
# Out:
# Cloning into '/content/nanoGPT-clone'...
# remote: Enumerating objects: 104, done.
# remote: Counting objects: 100% (104/104), done.
# remote: Compressing objects: 100% (72/72), done.
# remote: Total 104 (delta 62), reused 64 (delta 32), pack-reused 0 (from 0)
# Receiving objects: 100% (104/104), 771.37 KiB | 15.12 MiB/s, done.
# Resolving deltas: 100% (62/62), done.
# /content/nanoGPT-clone

# %%
# %run sample.py --init_from=gpt2 --start="I live in" --num_samples=1 --max_new_tokens=5 --device=cuda --show_probs=True --temperature=0.0001

# %%
# %run sample.py --init_from=gpt2 --start="I live in" --num_samples=1 --device=cuda --fixed_response_text=" a small house in the suburbs with my family"

# %%
# %run eval.py --init_from='gpt2' --num_samples=0
# Out:
# Overriding: init_from = gpt2
# loading weights from pretrained gpt: gpt2
# forcing vocab_size=50257, block_size=1024, bias=True
# overriding dropout rate to 0.0
# number of parameters: 123.65M
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:103: UserWarning:
# Error while fetching `HF_TOKEN` secret value from your vault: 'Requesting secret HF_TOKEN timed out. Secrets can only be fetched when running from the Colab UI.'.
# You are not authenticated with the Hugging Face Hub in this notebook.
# If the error persists, please let us know by opening an issue on GitHub (https://github.com/huggingface/huggingface_hub/issues/new).
#   warnings.warn(
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# No meta.pkl found, assuming GPT-2 encodings...
#
# - Fixed some crashes
#
# - Fixed some bugs for IE7
#
# - Fixed issue with text menus
#
# - Fixed a bug where data exported to script files was not created correctly
#
# - Fixed issue where screen manager could not be found when opening a file with 'auto-openwindow-dir' option
#
# - Fixed text editor not being able to load multiple windows
#
# - Fixed crash when deleting files
#
# - Fixed a crash when importing files from a file manager
#
# - Fixed crash when saving settings from a blank file manager
#
# - Fixed crash preventing more than one window from being open
#
# - Fixed a problem with loading computer applications
#
# - Fixed crash when importing crash statements to the clipboard
#
# - Fixed crash when importing a file at a different location
#
# - Fixed crash when importing a file in another folder
#
# - Fixed a crash when importing a file in a folder with more than one character length
#
# - Fixed a crash when importing multiple filetypes in separate windows
#
# - Fixed crash when importing multiple files with the same name
#
# - Fixed some layout bugs with the files dialog
#
# - Fixed some bugs with the text editor
#
# - Fixed a few crashes with the toolbar
#
# - Fixed a rare crash when saving a file with an empty path
#
# - Fixed some crashes when opening a window on a new computer
#
# - Fixed some crashes when clicking a window
#
# - Fixed a rare crash when installing a new program or application on a computer with the application window open and closes
#
# - Fixed a bug in some situations where the app window was not highlighted when opening a file window
#
# - Fixed a bug when closing a file editor when opening a file not being added
#
# - Fixed some crashes when editing files in a folder with more than one character length
#
# - Fixed some crashes when dragging a file selection to the clipboard
#
# - Fixed some crashes when exporting a file to a program that saves files with the option "open file window" in the group
#
# - Fixed some crashes when exporting a file in an event list
#
# - Fixed some crashes when importing an application with the option "open project" in the group
#
# - Fixed some crashes when importing an application with the option "open file" in the group
#
# - Fixed some crashes when importing application images in the group
#
# - Fixed some crashes when exporting an application in the group
#
# - Fixed some crashes when importing application files in
# ---------------
#
# Probability of generated sequence: 0.0
#
#
# From left: John Walsh, Ryan Johnson, Sarah Grouas, and Danny Thomas.
#
# The crowd, which was bigger than the majority of the audience, was still growing, even if it was growing slower than the other days.
#
# On Sunday morning, the crowd was a hair taller. Both teams moved in to practice, each feeling that they needed to get positive feedback or find room for improved practice.
#
# Advertisement
#
# In the first game, New Orleans wrapped up a win over the Bills. On Sunday, the same kind of momentum came back for the New York Giants, who played well against the Jets.
#
# "The first game, they were just really great," said Grouas, who was injured in New York's loss to the Rams. "They made plays."
#
# That said, the third-stringers never really got out of the way of the game, with the team's starting quarterback throwing a perfect interception on Sunday night.
#
# "You've got to do a good job of playing well in that offense," said Grouas, who threw for just 89 yards and two touchdowns on 56 carries. "If you lose your starting quarterback, you're just going to have to not be as good."
#
# Advertisement
#
# The game wasn't lost on the Jets, who ended their four-game winning streak on Sunday with a win over the Giants. They scored on points from Devonta Freeman (43 yards), Jake Matthews (31 yards), and Dominique Rodgers-Cromartie (11 yards).
#
# "Over the last two weeks we've had a hard time getting on the field (against the Giants)," said Rohan, who had two carries for 28 yards. "They're a good team and we have a good defense."
#
# Rodgers-Cromartie played well and caught a few passes for the Giants (22-3), which had a two-point deficit at the midway point of the fourth quarter.
#
# Grouas kept his footing. He made 10 tackles and recorded two tackles for loss. The only cornerback on the field with at least 40 tackles last season was LaRoche.
#
# "I thought we played really well," Grouas said of the Jets defense. "The good stuff in the first half was against the good stuff in the second half, but at the same time, we just tried to focus and get the ball in the end zone,
# ---------------
#
# Probability of generated sequence: 0.0
#
#
# A second time, she went to dinner with her father.
#
# "I did it to see if it would work," she said.
#
# "Once you get that, I'm glad to have someone who can explain it."
#
# There was only one problem.
#
# "It just doesn't work."
#
# "It's not right."
#
# "I'm sorry."
#
# When the father sat down to eat, a nervous expression appeared on her face.
#
# "It's all right."
#
# "Well you can actually be a very valuable person."
#
# "I'll be honest for now. I would like to do this myself."
#
# Kissing the father, she offered him a place to stay if he would stay up as long as he wanted.
#
# "Thank you."
#
# "Thank you…"
#
# She was the bride.
#
# After the ceremony, she disappeared into the house. She had been missing since April.
#
# She looked at the moment.
#
# The girl was trying to leave.
#
# "Is that the one who's going?"
#
# She imagined the dad like a son.
#
# "Mom!"
#
# "Dad! Mom!"
#
# She cried, with tears in her eyes.
#
# Kissing the mother, there was no answer.
#
# Trying to leave, she said, "Mom! Mom!".
#
# The father, who continued speaking, had also left the house.
#
# "I'm sorry."
#
# "I wasn't sure if it was because I was talking to Mom."
#
# "I had to leave!"
#
# "I guess it's because of that."
#
# "I, only told Mum…"
#
# "I thought you were going to make me kiss your face, but… Dad?"
#
# The girl simply stared at her.
#
# "So you don't want it?"
#
# "She just said she didn't want to be with you, but… she shouldn't be with you."
#
# "I want to… I just… I don't know."
#
# "You're not your own daughter or anything."
#
# Truly, Kollaina was indeed a weird woman.
#
# Kollaina and Kollaina the wife were both couples.
#
# The two didn't have children together.
#
# That's because Kollaina was the son of the family.
# ---------------
#
# Probability of generated sequence: 0.0
#
#
# The second reason for the need for the patent was that there were issues associated with having the patent for a product patented in this state. For example, if the patent was not issued under the present patent, it would not be eligible for issuance under the present patent if the invention does not include a material component with an active ingredient.
#
# The third reason for the requirement of a patent for a patent was that there was a high court decision that a patent cannot survive trial unless it succeeds in the application of the inventors features of a patented invention. The court therefore directed a plaintiff to make a filing showing that it satisfies the requirements of the patent requirements. Under the present patent, only the patent holder is required to file the filing with the Ohio State Board of Education in order to claim the patent. While this is a reasonable requirement if the patent is entitled to a license under the present patent, it will be of limited legal consequence if the evidence presented demonstrates that the patent holder did not file the filing, which will limit the patent's validity.
#
# The fourth reason for the requirement of a patent was due to the importance of obtaining a license to conduct the test for a patient for the current trial. The Ohio State Board of Education has long held that students should be certified to practice medicine by the Board of Medicine. Since the Ohio Board of Education has approved the issuance of the patent, the Ohio Rule of Procedure applies to the application of the Ohio Rule of Procedure for a registration and registration certificate of a patient for a trial. This certificate will be valid from the date of issuance unless the patient has been certified by the Ohio Board of Education pursuant to section 11-35-14.
#
# The fifth reason for the requirement of a patent was due to the fact that a patent holder's patents in this state are not subject to change. The Ohio State Board of Education frequently issues patent renewal applications for the class of inventions that have been patented in this state to pay a portion of the applicable license taxes due to the holder. The applicant for renewal will have to file with the Ohio State Board of Education a report that shows the type of research from the applicant, its origin, the establishment or the inventor and the date at which the patent expired. If the report shows that the patent has expired, the patent holder is obligated to file a renewal application with the Ohio State Board of Education stating the source of the research the patent holder conducted. The report is not required to show that the patent had a
# ---------------
#
# Probability of generated sequence: 0.0
#
# 'The whole world is watching. But they're not,' he said. 'What's happened to the rest of the world? What's happened to the political system?'
#
# They are living in the world where the US is the biggest trading partner with India.
#
# India's economic growth rate has fallen sharply in the last three years compared with previous years.
#
# India's domestic manufacturers and other exporters account for 18% of global GDP, with manufacturing including jewellery, fruits, machinery, vehicle parts and services.
#
# India is also the leading source of foreign exchange for the European Union and the US.
#
# Growth: The world economy is expected to grow by 2.4% over the next decade (stock image)
#
# India aims to have the world economy grow at least 3% a year, compared to growth in the US and Europe.
#
# Globalisation of trade and investment has been sharply slowing in recent years, though economic growth is expected to be slightly boosted in the coming years.
#
# India's growth rate for the third quarter was 1.1%, compared to last year's 1.5%.
#
# India is the world's largest exporter of agricultural products, which account for 3% of global GDP.<|endoftext|>I might have come across the following post on a blog:
#
# On a scale of 1 to 7, what is the worst thing that a person does when they seek help for something terrible, terrible, or upsetting them? Often the answer is something like, "I'm afraid that I'll die."
#
# Or, at least some of you might be.<|endoftext|>Many of the things I've heard about Donald Trump's rise when I asked him at a rally last weekend were ones he had already said many times before. "No disrespect to him" was the one I asked him about, but "He's not going to apologize, no one said anything to him at the rally". Some people who looked at him said it was more like, "We didn't ask a question. We didn't hear a question." While I don't believe the "no disrespect to him" comment made it into any of his campaign promises and was a joke, it certainly seems to be the sort of observation he's not looking for, and of course just as importantly he's not looking for anything.
#
# This was, after all, what's happened between us at every turn. The press, in my view, has been a
# ---------------
#
# Probability of generated sequence: 0.0
#
#
# Michele Proctor of K-Mart said it's the first time he's been diagnosed with Hodgkin's but it's not the first time he has been diagnosed with cancer.
#
# "There are a lot of things that go on with cancer, like inflammation, immune system.
#
# "I don't know if you should have an organ transplant or not. The reason for having an organ transplant is not just because it's been done by someone else.
#
# "The transplant takes a bit of radiation from somewhere.
#
# "It has to be done by someone else."
#
# Michele Proctor said he'll donate the organs to Movember - the annual international fundraiser for women from all over the world that celebrates ageing and our own body.
#
# He's also hoping volunteers will take part in the event too.
#
# "I think it's huge and it's inspirational," he said.<|endoftext|>The US intelligence community is weighing whether to take action over an alleged Russian hacking of the US Democratic National Committee, with US officials revealing that a special counsel is being investigated by the House Intelligence Committee.
#
# The complaint against Michael Dukakis, the former Georgia governor who was expelled from the Republican party over his ties to the Kremlin, lays out the scope of potential criminal charges against him, and why he should not be investigated.
#
# Speaking to Breitbart News, Dukakis' longtime communications director said that the report "would not be the same" under the Trump administration.
#
# "There is certainly a national/state question that needs to be answered," Dukakis said, adding that the committee "is looking at what the FBI, the CIA, the DOJ are doing with regard to this," which is why the committee "look at the reports that we have from the House intelligence panel, the Senate intelligence committee and various other sources."
#
# "We've already found a certain Russian connection of some sort to a number of members of the House Intelligence Committee," he said.
#
# "The question, and this is one of them, is whether the establishment media has the appropriate information to follow up on the information that they collect. There may be specific information that you would use in connection with that investigation to bring us to the same conclusion that we would have been looking at under the other administration," he continued.
#
# However, Dukakis himself acknowledged that he has no intention of moving forward on this or any other investigations so long as
# ---------------
#
# Probability of generated sequence: 0.0
#
#
# While the campaign had reported that Obama had not responded yet to a subpoena sent to him by the House Oversight Committee seeking information on the candidate's campaign activities, the data could be indicative of the broader nature of the investigation.
#
#
# There has been significant additional controversy about Obama's relationship with Russian officials. Yet the biggest problem for Obama, however, is the extent to which he is supporting the Russian government. Even though the intelligence community says Obama is undermining the FBI probe by leaking to the press information that may lead to indictments, he is refusing to provide any evidence to support his decision to make leaks public.
#
#
# Ultimately, the question remains: How can Obama claim to be one of the world's most committed and committed foreign policy leaders with a loyalty to Russian President Vladimir Putin and to Russia itself? On Sunday, another reason for Obama's refusal to turn over his files was that he was on the CIA's "red team" and had no idea who was in charge of the investigation into Russia's meddling in the 2016 election.
#
#
# Some commentators have proposed that the CIA's role in the investigation into the Russians' meddling is an indirect vote of confidence, since Obama had not authorized the CIA to conduct the investigation. But this is not the case. The CIA has been in the loop since 1998 and is fully compliant and cooperative with the White House. The New York Times' Andrew Ross Perot called this "a deliberate effort by Obama to use the CIA as a political pawn" in an article last month, despite a desire by some mainstream Democrats to accuse the CIA of trying to obstruct the investigation.
#
#
# That statement simply wasn't true. Obama's CIA ties are not necessarily connected to his campaign. The Agency served as the State Department's central body for coordinating intelligence and diplomacy in the region, in Afghanistan and elsewhere, and also as an important partner in the NATO coalition against the Islamic State of Iraq and the Levant.
#
#
# However, unlike the Obama administration where it had many contacts with Russian officials, the CIA was not in an official capacity as it must be to document President Vladimir Putin's behavior. It is possible, however, that this is due to the fact that Russia already had an eye on Obama, and the CIA did not want to risk a confrontation with Russia over the issue.
#
# At this point, the answer to the question of whether Obama has acknowledged the evidence of Russian interference in the U.S. election will be clear: If he has, he
# ---------------
#
# Probability of generated sequence: 0.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /content/nanoGPT-clone/eval.py in <module>
#       1 # eval.py
# ----> 2 from sample import *   # brings in model, ctx, encode, decode, etc.
#       3 import json
#       4
#       5 def eval():
#
# /content/nanoGPT-clone/sample.py in <module>
#      93             else:
#      94                 fixed_response = None
# ---> 95             y, seq_prob = model.generate(x,
#      96                                          max_new_tokens,
#      97                                          temperature=temperature,
#
# /usr/local/lib/python3.12/dist-packages/torch/utils/_contextlib.py in decorate_context(*args, **kwargs)
#     122         # pyrefly: ignore [bad-context-manager]
#     123         with ctx_factory():
# --> 124             return func(*args, **kwargs)
#     125
#     126     return decorate_context
#
# /content/nanoGPT-clone/model.py in generate(self, idx, max_new_tokens, temperature, top_k, show_probs, decode, fixed_response)
#     329             idx_cond = idx if idx.size(1) <= self.config.block_size else idx[:, -self.config.block_size:]
#     330             # forward the model to get the logits for the index in the sequence
# --> 331             logits, _ = self(idx_cond)
#     332             # pluck the logits at the final step and scale by desired temperature
#     333             logits = logits[:, -1, :] / temperature
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1774             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775         else:
# -> 1776             return self._call_impl(*args, **kwargs)
#    1777
#    1778     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1785                 or _global_backward_pre_hooks or _global_backward_hooks
#    1786                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787             return forward_call(*args, **kwargs)
#    1788
#    1789         result = None
#
# /content/nanoGPT-clone/model.py in forward(self, idx, targets)
#     189         else:
#     190             # inference-time mini-optimization: only forward the lm_head on the very last position
# --> 191             logits = self.lm_head(x[:, [-1], :]) # note: using list [-1] to preserve the time dim
#     192             loss = None
#     193
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1770         return result
#    1771
# -> 1772     def _wrapped_call_impl(self, *args, **kwargs):
#    1773         if self._compiled_call_impl is not None:
#    1774             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#
# KeyboardInterrupt:
