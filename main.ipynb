# %%
import os

repo_url = "https://github.com/Zedrion/nanoGPT-clone.git"
repo_path = "/content/nanoGPT-clone"

if os.path.exists(repo_path):
    # !git -C {repo_path} fetch --all 
    # !git -C {repo_path} reset --hard origin/main
else:
    # !git clone {repo_url} {repo_path}

# %cd {repo_path}
# %matplotlib inline
# Out:
# Cloning into '/content/nanoGPT-clone'...
# remote: Enumerating objects: 82, done.
# remote: Counting objects: 100% (82/82), done.
# remote: Compressing objects: 100% (58/58), done.
# remote: Total 82 (delta 48), reused 48 (delta 24), pack-reused 0 (from 0)
# Receiving objects: 100% (82/82), 763.69 KiB | 20.64 MiB/s, done.
# Resolving deltas: 100% (48/48), done.
# /content/nanoGPT-clone

# %%
# %run sample.py --init_from=gpt2 --start="I live in" --num_samples=1 --max_new_tokens=5 --device=cuda --show_probs=True --temperature=0.0001
# Out:
# Overriding: init_from = gpt2
# Overriding: start = I live in
# Overriding: num_samples = 1
# Overriding: max_new_tokens = 5
# Overriding: device = cuda
# Overriding: show_probs = True
# Overriding: temperature = 0.0001
# loading weights from pretrained gpt: gpt2
# forcing vocab_size=50257, block_size=1024, bias=True
# overriding dropout rate to 0.0
# number of parameters: 123.65M
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:103: UserWarning:
# Error while fetching `HF_TOKEN` secret value from your vault: 'Requesting secret HF_TOKEN timed out. Secrets can only be fetched when running from the Colab UI.'.
# You are not authenticated with the Hugging Face Hub in this notebook.
# If the error persists, please let us know by opening an issue on GitHub (https://github.com/huggingface/huggingface_hub/issues/new).
#   warnings.warn(
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# No meta.pkl found, assuming GPT-2 encodings...
# I live in a small town in the
# ---------------
#
# Probability of sequence: 0.5

# %%
# %run sample.py --init_from=gpt2 --start="I live in" --num_samples=1 --device=cuda --fixed_response_text="a small house in the suburbs with my family."
# Out:
# Overriding: init_from = gpt2
# Overriding: start = I live in
# Overriding: num_samples = 1
# Overriding: device = cuda
# Overriding: fixed_response_text = a small house in the suburbs with my family.
# loading weights from pretrained gpt: gpt2
# forcing vocab_size=50257, block_size=1024, bias=True
# overriding dropout rate to 0.0
# number of parameters: 123.65M
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# No meta.pkl found, assuming GPT-2 encodings...
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /content/nanoGPT-clone/sample.py in <module>
#      91             if fixed_response_text:
#      92                 fixed_response = encode(fixed_response_text)
# ---> 93             y, seq_prob = model.generate(x,
#      94                                          max_new_tokens,
#      95                                          temperature=temperature,
#
# /usr/local/lib/python3.12/dist-packages/torch/utils/_contextlib.py in decorate_context(*args, **kwargs)
#     122         # pyrefly: ignore [bad-context-manager]
#     123         with ctx_factory():
# --> 124             return func(*args, **kwargs)
#     125
#     126     return decorate_context
#
# /content/nanoGPT-clone/model.py in generate(self, idx, max_new_tokens, temperature, top_k, show_probs, decode, fixed_response)
#     369                 plt.close()
#     370             # append sampled index to the running sequence and continue
# --> 371             idx = torch.cat((idx, idx_next), dim=1)
#     372         # exponentiate log accumulation to get actual probability of sequence
#     373         sequence_prob = torch.exp(torch.tensor(sum_log_prob)).item()  # or import numpy/math and use numpy.exp()/math.exp()
#
# RuntimeError: Expected all tensors to be on the same device, but got tensors is on cpu, different from other tensors on cuda:0 (when checking argument in method wrapper_CUDA_cat)
