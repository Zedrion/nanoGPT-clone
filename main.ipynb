# %%
import os

repo_url = "https://github.com/Zedrion/nanoGPT-clone.git"
repo_path = "/content/nanoGPT-clone"

if os.path.exists(repo_path):
    # !git -C {repo_path} fetch --all 
    # !git -C {repo_path} reset --hard origin/main
else:
    # !git clone {repo_url} {repo_path}

# %cd {repo_path}
# %matplotlib inline
# Out:
# Cloning into '/content/nanoGPT-clone'...
# remote: Enumerating objects: 176, done.
# remote: Counting objects: 100% (176/176), done.
# remote: Compressing objects: 100% (126/126), done.
# remote: Total 176 (delta 95), reused 119 (delta 48), pack-reused 0 (from 0)
# Receiving objects: 100% (176/176), 1.36 MiB | 18.59 MiB/s, done.
# Resolving deltas: 100% (95/95), done.
# /content/nanoGPT-clone

# %%
# %run sample.py --init_from=gpt2 --start="I live in" --num_samples=1 --max_new_tokens=5 --device=cuda --show_probs=True --temperature=0.0001

# %%
# %run sample.py --init_from=gpt2 --start="I live in" --num_samples=1 --device=cuda --fixed_response_text=" a small house in the suburbs with my family"

# %%
# %run sample.py --init_from=gpt2 --start="My favorite person is" --num_samples=1 --device=cuda --fixed_response_text=" you"
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/IPython/core/magics/execution.py in run(self, parameter_s, runner, file_finder)
#     713             fpath = arg_lst[0]
# --> 714             filename = file_finder(fpath)
#     715         except IndexError:
#
# /usr/local/lib/python3.12/dist-packages/IPython/utils/path.py in get_py_filename(name, force_win32)
#     108     else:
# --> 109         raise IOError('File `%r` not found.' % name)
#     110
#
# OSError: File `'sample.py'` not found.
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# /tmp/ipykernel_12993/3417090085.py in <cell line: 0>()
# ----> 1 get_ipython().run_line_magic('run', 'sample.py --init_from=gpt2 --start="My favorite person is" --num_samples=1 --device=cuda --fixed_response_text=" you"')
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2416                 kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2417             with self.builtin_trap:
# -> 2418                 result = fn(*args, **kwargs)
#    2419             return result
#    2420
#
# <decorator-gen-52> in run(self, parameter_s, runner, file_finder)
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/magics/execution.py in run(self, parameter_s, runner, file_finder)
#     723             if os.name == 'nt' and re.match(r"^'.*'$",fpath):
#     724                 warn('For Windows, use double quotes to wrap a filename: %run "mypath\\myfile.py"')
# --> 725             raise Exception(msg)
#     726         except TypeError:
#     727             if fpath in sys.meta_path:
#
# Exception: File `'sample.py'` not found.

# %% [markdown]
# # 2.2.

# %%
# %run eval.py --init_from='gpt2' --num_samples=0

# %%
# %run data/hellaswag/prepare.py
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:103: UserWarning:
# Error while fetching `HF_TOKEN` secret value from your vault: 'Requesting secret HF_TOKEN timed out. Secrets can only be fetched when running from the Colab UI.'.
# You are not authenticated with the Hugging Face Hub in this notebook.
# If the error persists, please let us know by opening an issue on GitHub (https://github.com/huggingface/huggingface_hub/issues/new).
#   warnings.warn(
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# README.md: 0.00B [00:00, ?B/s]
# data/train-00000-of-00001.parquet:   0%|          | 0.00/24.4M [00:00<?, ?B/s]
# data/test-00000-of-00001.parquet:   0%|          | 0.00/6.11M [00:00<?, ?B/s]
# data/validation-00000-of-00001.parquet:   0%|          | 0.00/6.32M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/39905 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/10003 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/10042 [00:00<?, ? examples/s]
# train has 6,844,947 tokens
# val has 997,592 tokens

# %%
from google.colab import files
files.download('data/hellaswag/train.bin')
files.download('data/hellaswag/val.bin')

# %%
# %run train.py --init_from='gpt2' --dataset='hellaswag'
# Out:
# Overriding: init_from = gpt2
# Overriding: dataset = hellaswag
# tokens per iteration will be: 491,520
# Initializing from OpenAI GPT-2 weights: gpt2
# loading weights from pretrained gpt: gpt2
# forcing vocab_size=50257, block_size=1024, bias=True
# overriding dropout rate to 0.0
# number of parameters: 123.65M
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# /content/nanoGPT-clone/train.py:196: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler(enabled=(dtype == 'float16'))
# num decayed parameter tensors: 50, with 124,318,464 parameters
# num non-decayed parameter tensors: 98, with 121,344 parameters
# using fused AdamW: True
# compiling the model... (takes a ~minute)
# W0520 23:13:06.236000 12993 torch/_inductor/utils.py:1679] [0/0] Not enough SMs to use max_autotune_gemm mode
# /usr/local/lib/python3.12/dist-packages/torch/_inductor/compile_fx.py:2900: UserWarning: Tesla T4 does not support bfloat16 compilation natively, skipping
#   warnings.warn(
# step 0: train loss 2.7493, val loss 2.7768
# /usr/local/lib/python3.12/dist-packages/torch/_inductor/compile_fx.py:2900: UserWarning: Tesla T4 does not support bfloat16 compilation natively, skipping
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torch/_inductor/compile_fx.py:2900: UserWarning: Tesla T4 does not support bfloat16 compilation natively, skipping
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torch/_inductor/compile_fx.py:2900: UserWarning: Tesla T4 does not support bfloat16 compilation natively, skipping
#   warnings.warn(
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# /content/nanoGPT-clone/train.py in <module>
#     298             model.require_backward_grad_sync = (micro_step == gradient_accumulation_steps - 1)
#     299         with ctx:
# --> 300             logits, loss = model(X, Y)
#     301             loss = loss / gradient_accumulation_steps # scale the loss to account for gradient accumulation
#     302         # immediately async prefetch next batch while model is doing the forward pass on the GPU
#
# /usr/local/lib/python3.12/dist-packages/torch/_dynamo/eval_frame.py in __call__(self, *args, **kwargs)
#     463             )
#     464         with _set_in_optimized_module():
# --> 465             return super().__call__(*args, **kwargs)
#     466
#     467     def _aot_compile(self, inputs: list[torch._dynamo.aot_compile.ModelInput]) -> None:
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1774             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775         else:
# -> 1776             return self._call_impl(*args, **kwargs)
#    1777
#    1778     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1785                 or _global_backward_pre_hooks or _global_backward_hooks
#    1786                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787             return forward_call(*args, **kwargs)
#    1788
#    1789         result = None
#
# /usr/local/lib/python3.12/dist-packages/torch/_dynamo/eval_frame.py in compile_wrapper(*args, **kwargs)
#     951
#     952                 try:
# --> 953                     return fn(*args, **kwargs)
#     954                 except Unsupported as e:
#     955                     if config.verbose:
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1774             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775         else:
# -> 1776             return self._call_impl(*args, **kwargs)
#    1777
#    1778     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1785                 or _global_backward_pre_hooks or _global_backward_hooks
#    1786                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787             return forward_call(*args, **kwargs)
#    1788
#    1789         result = None
#
# /content/nanoGPT-clone/model.py in forward(self, idx, targets)
#     186             # if we are given some desired targets also calculate the loss
#     187             logits = self.lm_head(x)
# --> 188             loss = F.cross_entropy(logits.view(-1, logits.size(-1)), targets.view(-1), ignore_index=-1)
#     189         else:
#     190             # inference-time mini-optimization: only forward the lm_head on the very last position
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/functional.py in cross_entropy(input, target, weight, size_average, ignore_index, reduce, reduction, label_smoothing)
#    3502     if size_average is not None or reduce is not None:
#    3503         reduction = _Reduction.legacy_get_string(size_average, reduce)
# -> 3504     return torch._C._nn.cross_entropy_loss(
#    3505         input,
#    3506         target,
#
# OutOfMemoryError: CUDA out of memory. Tried to allocate 1.15 GiB. GPU 0 has a total capacity of 14.56 GiB of which 985.81 MiB is free. Including non-PyTorch memory, this process has 13.60 GiB memory in use. Of the allocated memory 13.17 GiB is allocated by PyTorch, and 309.60 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)

# %%
# %run eval.py --init_from='resume' --num_samples=0 > finetuned_eval.txt
