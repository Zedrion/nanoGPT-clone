# %%
# !git clone https://github.com/Zedrion/nanoGPT-clone.git /content/nanoGPT-clone
# %cd /content/nanoGPT-clone
# %matplotlib inline
# Out:
# fatal: destination path '/content/nanoGPT-clone' already exists and is not an empty directory.
# /content/nanoGPT-clone

# %%
# %run sample.py --init_from=gpt2 --start="I want to be right where you are." --num_samples=1 --max_new_tokens=20 --device=cuda --show_probs=True --temperature=2.0
# Out:
# Overriding: init_from = gpt2
# Overriding: start = I want to be right where you are.
# Overriding: num_samples = 1
# Overriding: max_new_tokens = 20
# Overriding: device = cuda
# Overriding: show_probs = True
# Overriding: temperature = 2.0
# loading weights from pretrained gpt: gpt2
# forcing vocab_size=50257, block_size=1024, bias=True
# overriding dropout rate to 0.0
# number of parameters: 123.65M
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# No meta.pkl found, assuming GPT-2 encodings...
# I want to be right where you are. Have any room to move around? If we be giving somuch additional material for women' support how
# ---------------
