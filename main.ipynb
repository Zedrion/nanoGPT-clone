# %%
# !python sample.py --init_from=gpt2 --start="Am I Dreaming" --num_samples=5 --max_new_tokens=20 --device=gpu
# Out:
# python3: can't open file '/content/sample.py': [Errno 2] No such file or directory
