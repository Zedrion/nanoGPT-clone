# %%
import os

repo_url = "https://github.com/Zedrion/nanoGPT-clone.git"
repo_path = "/content/nanoGPT-clone"

if os.path.exists(repo_path):
    # !git -C {repo_path} fetch --all 
    # !git -C {repo_path} reset --hard origin/main
else:
    # !git clone {repo_url} {repo_path}

# %cd {repo_path}
# %matplotlib inline

# %%
# %run sample.py --init_from=gpt2 --start="I live in" --num_samples=1 --max_new_tokens=5 --device=cuda --show_probs=True --temperature=0.0001

# %%
# %run sample.py --init_from=gpt2 --start="I live in" --num_samples=1 --device=cuda --fixed_response_text=" a small house in the suburbs with my family"

# %%
# %run sample.py --init_from=gpt2 --start="My favorite person is" --num_samples=1 --device=cuda --fixed_response_text=" you"

# %% [markdown]
# # 2.2.

# %%
# %run eval.py --init_from='gpt2' --num_samples=0

# %%
# %run eval.py --init_from='gpt2' --num_samples=0 > baseline_eval.txt

# %%
# %run train.py --init_from='gpt2' --dataset='shakespeare'
# Out:
# Overriding: init_from = gpt2
# Overriding: dataset = shakespeare
# tokens per iteration will be: 491,520
# Initializing from OpenAI GPT-2 weights: gpt2
# loading weights from pretrained gpt: gpt2
# forcing vocab_size=50257, block_size=1024, bias=True
# overriding dropout rate to 0.0
# number of parameters: 123.65M
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# num decayed parameter tensors: 50, with 124,318,464 parameters
# num non-decayed parameter tensors: 98, with 121,344 parameters
# using fused AdamW: True
# compiling the model... (takes a ~minute)
# /content/nanoGPT-clone/train.py:196: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler(enabled=(dtype == 'float16'))
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /content/nanoGPT-clone/train.py in <module>
#     248
#     249 # training loop
# --> 250 X, Y = get_batch('train') # fetch the very first batch
#     251 t0 = time.time()
#     252 local_iter_num = 0 # number of iterations in the lifetime of this process
#
# /content/nanoGPT-clone/train.py in get_batch(split)
#     118     # https://stackoverflow.com/questions/45132940/numpy-memmap-memory-usage-want-to-iterate-once/61472122#61472122
#     119     if split == 'train':
# --> 120         data = np.memmap(os.path.join(data_dir, 'train.bin'), dtype=np.uint16, mode='r')
#     121     else:
#     122         data = np.memmap(os.path.join(data_dir, 'val.bin'), dtype=np.uint16, mode='r')
#
# /usr/local/lib/python3.12/dist-packages/numpy/_core/memmap.py in __new__(subtype, filename, dtype, mode, offset, shape, order)
#     231             f_ctx = nullcontext(filename)
#     232         else:
# --> 233             f_ctx = open(
#     234                 os.fspath(filename),
#     235                 ('r' if mode == 'c' else mode)+'b'
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/shakespeare/train.bin'

# %%
# %run eval.py --init_from='resume' --num_samples=0 > finetuned_eval.txt
