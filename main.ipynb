# %%
# !git clone https://github.com/Zedrion/nanoGPT-clone.git /content/nanoGPT-clone
# %cd /content/nanoGPT-clone

# %%
# !python sample.py --init_from=gpt2 --start="Stand proud. You are strong." --num_samples=5 --max_new_tokens=100 --device=cuda --show_probs=True
